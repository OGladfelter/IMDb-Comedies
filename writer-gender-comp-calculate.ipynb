# %% [markdown]
# ## Calculating Gender Composition from Writers List
#
# Author: Oliver Gladfelter
#
# Date: 4/25/18

# %%
import pandas as pd
import numpy as np

episodesData = pd.read_csv("top10ComediesWithWriters.csv", encoding='latin-1')
episodesData = episodesData.replace(np.nan, '', regex=True)

# %%
episodesData.head(3)
# Out:
#       tconst        primaryTitle  startYear runtimeMinutes  averageRating  \
# 0  tt0515236               Pilot       2003             21            8.3
# 1  tt0515256          Top Banana       2003             22            8.6
# 2  tt0515212  Bringing Up Buster       2003             22            8.2
#
#    numVotes parentTconst                series  episodeNumberInt  \
# 0      2290    tt0367279  Arrested Development                 1
# 1      1986    tt0367279  Arrested Development                 2
# 2      1826    tt0367279  Arrested Development                 3
#
#    seasonNumberInt  totalNum  \
# 0                1         1
# 1                1         2
# 2                1         3
#
#                                              writers
# 0                                   Mitchell Hurwitz
# 1  Abraham Higginbotham, Mitchell Hurwitz, John L...
# 2  Richard Rosenstock, Mitchell Hurwitz, Abraham ...

# %%
import json

from urllib.request import urlopen

# to determine writer gender based on name, we use the Gender API found at https://gender-api.com/

# key obtained from Gender API
myKey = ""

def writerGender(writer):
    """
    Given a full writer name (ex: "Oliver Gladfelter), call the Gender API on the first name
    and return a list containing the predicted gender of name and confidence level
    """
    url = "https://gender-api.com/get?key=" + myKey + "&name=" + writer.split(' ')[0]
    response = urlopen(url)
    decoded = response.read().decode('utf-8')
    data = json.loads(decoded)

    return [data['gender'], data['accuracy']]

# %% [markdown]
# Although we now have an API and accompanying function to derive gender from a writer's name, we do not want to apply these to the episodesData data frame itself. Because unique writer values often repeat (as in most writers write multiple episodes), this would result in calling the API over 11,000 times, which is problematic. Instead, we want to create a new dataframe, in which each writer and their corresponding gender is observed once. This smaller dataframe will act as a key.

# %%
writerDict = {}

# because each episodes' writers are stored as a single string, 
# seperated by commas, create a list of writers by using str.split()
for episode in range(0, len(episodesData)): 
    writersNoSpace = episodesData['writers'][episode].replace(', ', ',')
    episodesWriters = writersNoSpace.split(',')
    
    # for each writer in the list, add to the dictionary of writers
    for writer in episodesWriters:
        if writer not in writerDict:
            writerDict[writer] = 1
        else: 
            writerDict[writer] = writerDict[writer] + 1

# %%
# convert dictionary into a dataframe
writerDictDF = pd.DataFrame(list(writerDict.items()), columns=['Writer', 'Episodes Written'])
writerDictDF = writerDictDF.sort_values(by = 'Episodes Written', ascending = False)
writerDictDF = writerDictDF.reset_index()
del writerDictDF['index']
writerDictDF.head()
# Out:
#             Writer  Episodes Written
# 0  James L. Brooks               630
# 1    Matt Groening               630
# 2        Sam Simon               630
# 3  David Zuckerman               304
# 4  Seth MacFarlane               304

# %% [markdown]
# This new dataframe includes only 472 observations, one for each unique writer found in the episodesData dataframe. We can now apply the writerGender() function defined above to determine the gender of each writer. Once calculated, two supporting functions seperate the returned gender and prediction accuracy list into seperate values, attaching each as columns to the dataframe.

# %%
writerDictDF['genderAndAccuracy'] = ''

writerDictDF['genderAndAccuracy'] = writerDictDF['Writer'].apply(writerGender)

def getGender(value):
    return value[0]

def getAccuracy(value):
    return value[1]

writerDictDF['gender'] = ''
writerDictDF['gender'] = writerDictDF['genderAndAccuracy'].apply(getGender)
writerDictDF['accuracy'] = ''
writerDictDF['accuracy'] = writerDictDF['genderAndAccuracy'].apply(getAccuracy)

del writerDictDF['genderAndAccuracy']

# %%
writerDictDF.head()
# Out:
#             Writer  Episodes Written gender  accuracy
# 0  James L. Brooks               630   male        99
# 1    Matt Groening               630   male       100
# 2        Sam Simon               630   male        85
# 3  David Zuckerman               304   male        99
# 4  Seth MacFarlane               304   male        99

# %%
writerDictDF.to_csv("C:\\Users\\Oliver\\Documents\\imbd episodes\\genderOfWriters.csv")

# %% [markdown]
# Now that we have obtained the gender for each writer, the next step is to add genders to the episodesData dataframe. A merge between the two dataframes would not be successful because multiple writers are recorded single strings in the episodesData dataframe. Instead, we create a third dataframe, in which each writer of each episode is listed individually in a row. This will allow for a merge with the writerDictDF dataframe.

# %%
writingStaff = []

for index, row in episodesData.iterrows():
    
    if row['writers'] != r'\N':
        episodes = row['tconst']
        writerGenders = row['writers']
        
        # for each writer included in the writers column of episodesData, create a new row for that writer
        for writer in writerGenders.split(','):
            newRow = [episodes, writer]
            writingStaff.append(newRow)

writingStaffDF = pd.DataFrame(writingStaff, columns = ['tconst', 'Writer'])

# %%
writingStaffDF2 = writingStaffDF.sort_values(by = 'Writer')
writerDictDF2 = writerDictDF.sort_values(by = 'Writer')

def stripSpace(value):
    return value.strip(' ')
    
writingStaffDF2['Writer'] = writingStaffDF2['Writer'].apply(stripSpace)
writerDictDF2['Writer'] = writerDictDF2['Writer'].apply(stripSpace)

# %%
writingStaffDF2.head(10)
# Out:
#           tconst            Writer
# 11370  tt7852294
# 1082   tt1795203  Aaron Blitzstein
# 1058   tt1819898  Aaron Blitzstein
# 1029   tt1758140  Aaron Blitzstein
# 1016   tt1610753  Aaron Blitzstein
# 1066   tt1795201  Aaron Blitzstein
# 1127   tt1795206  Aaron Blitzstein
# 1010   tt1610752  Aaron Blitzstein
# 1103   tt1795207  Aaron Blitzstein
# 1038   tt1759063  Aaron Blitzstein

# %%
writerDictDF2.head(10)
# Out:
#                    Writer  Episodes Written   gender  accuracy
# 470                                       1  unknown         0
# 117      Aaron Blitzstein                16     male        99
# 24            Aaron Korsh               103     male        99
# 264             Aaron Lee                 4     male        99
# 224           Aaron Shure                 6     male        99
# 326           Abed Gheith                 2     male        97
# 41   Abraham Higginbotham                48     male        99
# 123            Adam Chase                16     male        99
# 66          Adam Faberman                29     male        99
# 447       Adam I. Lapidus                 1     male        99

# %%
writingStaffWithGender = writingStaffDF2.merge(writerDictDF2, how = 'left')
writingStaffWithGender = writingStaffWithGender.sort_values(by = 'tconst')
writingStaffWithGender = writingStaffWithGender.reset_index()
del writingStaffWithGender['index']

# %%
# add a new column of blank strings
writingStaffWithGender['writerGenders'] = ''

# iterate over the length of the data frame in order to create full lists of writers involved, rather
# than having writing staffs seperated over multiple rows
for writer in range(0, len(writingStaffWithGender) - 1):
    
    # create a variable holding the string of the writers name for current row
    genders = writingStaffWithGender['gender'][writer]
    count = 1
    
    # while subsequent rows contain information about the current row's same movie, add the writer's
    # names to the 'names' variable. 
    while writingStaffWithGender['tconst'][writer] == writingStaffWithGender['tconst'][writer + count]:
        genders = genders + "," + writingStaffWithGender['gender'][writer + count]
        count = count + 1
        
    # once the last row for the given movie is reached and all writers have been added to the 
    # 'names' variable, replace the empty string in the 'writers' column with the string held by 'names'
    writingStaffWithGender['writerGenders'][writer] = genders

# %%
writingStaffWithGender.head()
# Out:
#       tconst             Writer  Episodes Written gender  accuracy  \
# 0  tt0177842  John Swartzwelder                59   male        99
# 1  tt0177842    James L. Brooks               630   male        99
# 2  tt0177842     Steve Tompkins                 4   male        99
# 3  tt0177842      Matt Groening               630   male       100
# 4  tt0177842     David X. Cohen                35   male        99
#
#                         writerGenders
# 0  male,male,male,male,male,male,male
# 1       male,male,male,male,male,male
# 2            male,male,male,male,male
# 3                 male,male,male,male
# 4                      male,male,male

# %% [markdown]
# We now have a dataframe of episode title IDs and corresponding gender compositions, in string list form. However, each episode is listed multiple times, once for each writer. Additionally, the full gender compositions (including the gender of every writer for a given episode) are only included in the first instance of each episode. Thus, the final step is to drop duplicate episode IDs, keeping only the first instance, and deleting the unhelpful columns.

# %%
# drop duplicate episodes in the data frame, always keeping the first instance of each repeated movie
# because the full writing staffs are only included in the first instance
writingStaffWithGender2 = writingStaffWithGender.drop_duplicates(subset = 'tconst', keep = 'first')

writingStaffWithGender2 = writingStaffWithGender2.drop(['gender', 'Episodes Written', 'Writer', 'gender', 'accuracy'], axis = 1)

writingStaffWithGender2 = writingStaffWithGender2.reset_index()
del writingStaffWithGender2['index']

writingStaffWithGender2.head()
# Out:
#       tconst                       writerGenders
# 0  tt0177842  male,male,male,male,male,male,male
# 1  tt0348034               male,male,male,female
# 2  tt0394893                 male,male,male,male
# 3  tt0458217                      male,male,male
# 4  tt0515207                      male,male,male

# %% [markdown]
# Finally, we have a proper dataframe containing each TV episode and the genders of each writer for that episode. This is merged with the episodesData dataframe, pulling all necessary data together.

# %%
# attach each episode's writing staff to our main dataframe, topComediesOrdered
episodesDataWithGenderComp = episodesData.merge(writingStaffWithGender2, how = "inner", on = "tconst")

episodesDataWithGenderComp.head(3)
# Out:
#       tconst        primaryTitle  startYear runtimeMinutes  averageRating  \
# 0  tt0515236               Pilot       2003             21            8.3
# 1  tt0515256          Top Banana       2003             22            8.6
# 2  tt0515212  Bringing Up Buster       2003             22            8.2
#
#    numVotes parentTconst                series  episodeNumberInt  \
# 0      2290    tt0367279  Arrested Development                 1
# 1      1986    tt0367279  Arrested Development                 2
# 2      1826    tt0367279  Arrested Development                 3
#
#    seasonNumberInt  totalNum  \
# 0                1         1
# 1                1         2
# 2                1         3
#
#                                              writers   writerGenders
# 0                                   Mitchell Hurwitz            male
# 1  Abraham Higginbotham, Mitchell Hurwitz, John L...  male,male,male
# 2  Richard Rosenstock, Mitchell Hurwitz, Abraham ...  male,male,male

# %%
# Confirming all dataframes are of equal length...
print(len(writingStaffWithGender2))
print(len(episodesData))
print(len(episodesDataWithGenderComp))
# Out:
# 2512
# 2512
# 2512

# %%
def calculateGenderComp(value):
    """
    Given a list of individuals' genders in comma-seperated string format, 
    return the proportion of males included in the list
    """
    
    listOfGender = value.split(',')
    
    numMaleWriters = 0
    
    for writerGender in listOfGender:
        if writerGender == 'male':
            numMaleWriters = numMaleWriters + 1
            
    return numMaleWriters / len(listOfGender)


episodesDataWithGenderComp['perMaleWrite'] = 0
episodesDataWithGenderComp['perMaleWrite'] = episodesDataWithGenderComp['writerGenders'].apply(calculateGenderComp)

# %%
episodesDataWithGenderComp
# Out:
#          tconst                                      primaryTitle  startYear  \
# 0     tt0515236                                             Pilot       2003
# 1     tt0515256                                        Top Banana       2003
# 2     tt0515212                                Bringing Up Buster       2003
# 3     tt0515223                                     Key Decisions       2003
# 4     tt0515214                                     Charity Drive       2003
# 5     tt0515257                                     Visiting Ours       2003
# 6     tt0515221                                   In God We Trust       2003
# 7     tt0515231                                 My Mother the Car       2003
# 8     tt0515247                               Storming the Castle       2004
# 9     tt0515235                                     Pier Pressure       2004
# 10    tt0515238                                  Public Relations       2004
# 11    tt0515226                                     Marta Complex       2004
# 12    tt0515210                                     Beef Consomme       2004
# 13    tt0515244                                     Shock and Aww       2004
# 14    tt0515246                                   Staff Infection       2004
# 15    tt0515208                                        Altar Egos       2004
# 16    tt0515222                                  Justice Is Blind       2004
# 17    tt0515228                                     Missing Kitty       2004
# 18    tt0515211                              Best Man for the Gob       2004
# 19    tt0515258                                 Whistler's Mother       2004
# 20    tt0515232                           Not Without My Daughter       2004
# 21    tt0515224                                  Let 'Em Eat Cake       2004
# 22    tt0515253                      The One Where Michael Leaves       2004
# 23    tt0515254                  The One Where They Build a House       2004
# 24    tt0515209                                            Amigos       2004
# 25    tt0515219                                       Good Grief!       2004
# 26    tt0515243                                          Sad Sack       2004
# 27    tt0515207                                 Afternoon Delight       2004
# 28    tt0515248                                     Switch Hitter       2005
# 29    tt0515239                                   Queen for a Day       2005
# ...         ...                                               ...        ...
# 2482  tt5847448                                There Will Be Buds       2016
# 2483  tt5222762                               Havana Wild Weekend       2016
# 2484  tt4765710                                      Dad Behavior       2016
# 2485  tt5847466                            The Last Traction Hero       2016
# 2486  tt5570642                      The Nightmare After Krustmas       2016
# 2487  tt5847488                                    Pork and Burns       2017
# 2488  tt5847482                         The Great Phatsby: Part 1       2017
# 2489  tt7410954                         The Great Phatsby: Part 2       2017
# 2490  tt5847490                                      Fatzcarraldo       2017
# 2491  tt5847492                               The Cad and the Hat       2017
# 2492  tt5847434                                     Kamp Krustier       2017
# 2493  tt4765712                                         22 for 30       2017
# 2494  tt6012538                                  A Father's Watch       2017
# 2495  tt6012540                                   The Caper Chase       2017
# 2496  tt5951416                          Looking for Mr. Goodbart       2017
# 2497  tt5951430                                        Moho House       2017
# 2498  tt6733170                                           Dogtown       2017
# 2499  tt7156270                                      The Serfsons       2017
# 2500  tt7156264                              Springfield Splendor       2017
# 2501  tt6225292                                 Whistler's Father       2017
# 2502  tt6890620                        Treehouse of Horror XXVIII       2017
# 2503  tt7480030                             Grampy Can Ya Hear Me       2017
# 2504  tt7548148  The Old Blue Mayor She Ain't What She Used To Be       2017
# 2505  tt7368116                               Singin' in the Lane       2017
# 2506  tt7343996                                   Mr. Lisa's Opus       2017
# 2507  tt7480064                                          Gone Boy       2017
# 2508  tt7156278                                      Haw-Haw Land       2018
# 2509  tt6890594                                  Frink Gets Testy       2018
# 2510  tt7852294                      Homer is Where the Art Isn't       2018
# 2511  tt7343988               3 Scenes Plus a Tag from a Marriage       2018
#
#      runtimeMinutes  averageRating  numVotes parentTconst  \
# 0                21            8.3      2290    tt0367279
# 1                22            8.6      1986    tt0367279
# 2                22            8.2      1826    tt0367279
# 3                21            8.5      1739    tt0367279
# 4                21            8.4      1647    tt0367279
# 5                21            8.2      1600    tt0367279
# 6                21            8.2      1563    tt0367279
# 7                21            8.2      1549    tt0367279
# 8                22            8.5      1520    tt0367279
# 9                22            9.2      1956    tt0367279
# 10               22            8.3      1519    tt0367279
# 11               22            8.5      1470    tt0367279
# 12               22            8.5      1463    tt0367279
# 13               22            8.7      1502    tt0367279
# 14               22            8.3      1418    tt0367279
# 15               22            8.6      1439    tt0367279
# 16               22            8.8      1470    tt0367279
# 17               22            8.4      1375    tt0367279
# 18               22            8.3      1364    tt0367279
# 19               22            8.1      1353    tt0367279
# 20               22            8.7      1374    tt0367279
# 21               22            8.8      1416    tt0367279
# 22               30            8.8      1360    tt0367279
# 23               30            8.7      1367    tt0367279
# 24               30            8.9      1444    tt0367279
# 25               30            9.1      1564    tt0367279
# 26               30            8.7      1281    tt0367279
# 27               30            9.1      1603    tt0367279
# 28               30            8.3      1247    tt0367279
# 29               30            8.2      1216    tt0367279
# ...             ...            ...       ...          ...
# 2482             22            6.8       403    tt0096697
# 2483             21            6.2       401    tt0096697
# 2484             21            6.7       379    tt0096697
# 2485             21            6.4       363    tt0096697
# 2486             22            6.0       383    tt0096697
# 2487             23            7.0       392    tt0096697
# 2488             60            6.4       497    tt0096697
# 2489             \N            5.9       157    tt0096697
# 2490             21            6.3       359    tt0096697
# 2491             \N            6.5       356    tt0096697
# 2492             \N            6.6       358    tt0096697
# 2493             21            6.5       368    tt0096697
# 2494             21            6.9       349    tt0096697
# 2495             21            6.1       375    tt0096697
# 2496             21            6.9       365    tt0096697
# 2497             21            6.1       322    tt0096697
# 2498             21            6.5       325    tt0096697
# 2499             21            6.8       499    tt0096697
# 2500             21            6.5       376    tt0096697
# 2501             21            6.1       312    tt0096697
# 2502             21            7.1       416    tt0096697
# 2503             21            6.2       277    tt0096697
# 2504             21            6.3       278    tt0096697
# 2505             21            6.3       272    tt0096697
# 2506             21            6.8       283    tt0096697
# 2507             21            7.2       274    tt0096697
# 2508             21            6.5       262    tt0096697
# 2509             21            6.1       235    tt0096697
# 2510             21            6.6       211    tt0096697
# 2511             \N            6.7       137    tt0096697
#
#                     series  episodeNumberInt  seasonNumberInt  totalNum  \
# 0     Arrested Development                 1                1         1
# 1     Arrested Development                 2                1         2
# 2     Arrested Development                 3                1         3
# 3     Arrested Development                 4                1         4
# 4     Arrested Development                 5                1         5
# 5     Arrested Development                 6                1         6
# 6     Arrested Development                 7                1         7
# 7     Arrested Development                 8                1         8
# 8     Arrested Development                 9                1         9
# 9     Arrested Development                10                1        10
# 10    Arrested Development                11                1        11
# 11    Arrested Development                12                1        12
# 12    Arrested Development                13                1        13
# 13    Arrested Development                14                1        14
# 14    Arrested Development                15                1        15
# 15    Arrested Development                16                1        16
# 16    Arrested Development                17                1        17
# 17    Arrested Development                18                1        18
# 18    Arrested Development                19                1        19
# 19    Arrested Development                20                1        20
# 20    Arrested Development                21                1        21
# 21    Arrested Development                22                1        22
# 22    Arrested Development                 1                2        23
# 23    Arrested Development                 2                2        24
# 24    Arrested Development                 3                2        25
# 25    Arrested Development                 4                2        26
# 26    Arrested Development                 5                2        27
# 27    Arrested Development                 6                2        28
# 28    Arrested Development                 7                2        29
# 29    Arrested Development                 8                2        30
# ...                    ...               ...              ...       ...
# 2482          The Simpsons                 6               28       602
# 2483          The Simpsons                 7               28       603
# 2484          The Simpsons                 8               28       604
# 2485          The Simpsons                 9               28       605
# 2486          The Simpsons                10               28       606
# 2487          The Simpsons                11               28       607
# 2488          The Simpsons                12               28       608
# 2489          The Simpsons                13               28       609
# 2490          The Simpsons                14               28       610
# 2491          The Simpsons                15               28       611
# 2492          The Simpsons                16               28       612
# 2493          The Simpsons                17               28       613
# 2494          The Simpsons                18               28       614
# 2495          The Simpsons                19               28       615
# 2496          The Simpsons                20               28       616
# 2497          The Simpsons                21               28       617
# 2498          The Simpsons                22               28       618
# 2499          The Simpsons                 1               29       619
# 2500          The Simpsons                 2               29       620
# 2501          The Simpsons                 3               29       621
# 2502          The Simpsons                 4               29       622
# 2503          The Simpsons                 5               29       623
# 2504          The Simpsons                 6               29       624
# 2505          The Simpsons                 7               29       625
# 2506          The Simpsons                 8               29       626
# 2507          The Simpsons                 9               29       627
# 2508          The Simpsons                10               29       628
# 2509          The Simpsons                11               29       629
# 2510          The Simpsons                12               29       630
# 2511          The Simpsons                13               29       631
#
#                                                 writers  \
# 0                                      Mitchell Hurwitz
# 1     Abraham Higginbotham, Mitchell Hurwitz, John L...
# 2     Richard Rosenstock, Mitchell Hurwitz, Abraham ...
# 3     Brad Copeland, Mitchell Hurwitz, Abraham Higgi...
# 4     Barbie Adler, Mitchell Hurwitz, Abraham Higgin...
# 5     John Levenstein, Richard Rosenstock, Mitchell ...
# 6                Abraham Higginbotham, Mitchell Hurwitz
# 7     Mitchell Hurwitz, Abraham Higginbotham, Chuck ...
# 8     Mitchell Hurwitz, Abraham Higginbotham, Brad C...
# 9     Abraham Higginbotham, Mitchell Hurwitz, James ...
# 10    Courtney Lilly, Abraham Higginbotham, Mitchell...
# 11    John Levenstein, Mitchell Hurwitz, James Valle...
# 12    Chuck Martin, Abraham Higginbotham, Mitchell H...
# 13    Abraham Higginbotham, Chuck Martin, James Vall...
# 14    Abraham Higginbotham, Mitchell Hurwitz, Brad C...
# 15    Mitchell Hurwitz, Barbie Adler, Abraham Higgin...
# 16               Abraham Higginbotham, Mitchell Hurwitz
# 17    Abraham Higginbotham, John Levenstein, Mitchel...
# 18    Mitchell Hurwitz, Richard Rosenstock, Abraham ...
# 19    John Levenstein, Abraham Higginbotham, James V...
# 20    Abraham Higginbotham, Richard Rosenstock, Mitc...
# 21    Abraham Higginbotham, Mitchell Hurwitz, James ...
# 22                 Mitchell Hurwitz, Richard Rosenstock
# 23                      Mitchell Hurwitz, James Vallely
# 24                      Brad Copeland, Mitchell Hurwitz
# 25                    John Levenstein, Mitchell Hurwitz
# 26                       Barbie Adler, Mitchell Hurwitz
# 27    Mitchell Hurwitz, Abraham Higginbotham, Chuck ...
# 28       Mitchell Hurwitz, Courtney Lilly, Barbie Adler
# 29                      Brad Copeland, Mitchell Hurwitz
# ...                                                 ...
# 2482  James L. Brooks, Matt Groening, Sam Simon, Mat...
# 2483  Matt Groening, Deb Lacusta, Dan Castellaneta, ...
# 2484  James L. Brooks, Sam Simon, Ryan Koh, Matt Gro...
# 2485  James L. Brooks, Matt Groening, Bill Odenkirk,...
# 2486  James L. Brooks, Matt Groening, Jeff Westbrook...
# 2487  Sam Simon, Rob LaZebnik, Matt Groening, James ...
# 2488  Sam Simon, Dan Greaney, Matt Groening, James L...
# 2489  Dan Greaney, James L. Brooks, Matt Groening, M...
# 2490  Sam Simon, Matt Groening, James L. Brooks, Mic...
# 2491  James L. Brooks, Tom Root, Ron Zimmerman, Sam ...
# 2492  Matt Groening, James L. Brooks, David M. Stern...
# 2493  Sam Simon, Matt Groening, Joel H. Cohen, James...
# 2494  Matt Groening, James L. Brooks, Sam Simon, Sim...
# 2495  Matt Groening, James L. Brooks, Sam Simon, Jef...
# 2496  Matt Groening, James L. Brooks, Carolyn Omine,...
# 2497  Sam Simon, Jeff Martin, Matt Groening, James L...
# 2498  Matt Groening, Sam Simon, J. Stewart Burns, Ja...
# 2499  Brian Kelley, Sam Simon, James L. Brooks, Matt...
# 2500  Miranda Thompson, Sam Simon, Matt Groening, Ja...
# 2501  Tom Gammill, Sam Simon, James L. Brooks, Max P...
# 2502  Sam Simon, John Frink, James L. Brooks, Matt G...
# 2503  Sam Simon, Matt Groening, James L. Brooks, Bil...
# 2504  Sam Simon, Tom Gammill, Max Pross, James L. Br...
# 2505  Sam Simon, James L. Brooks, Ryan Koh, Matt Gro...
# 2506  James L. Brooks, Al Jean, Sam Simon, Matt Groe...
# 2507  John Frink, Matt Groening, Sam Simon, James L....
# 2508  Miranda Thompson, Tim Long, Matt Groening, Jam...
# 2509  Matt Groening, Sam Simon, James L. Brooks, Dan...
# 2510
# 2511  Sam Simon, Max Pross, James L. Brooks, Tom Gam...
#
#                         writerGenders  perMaleWrite
# 0                                male      1.000000
# 1                      male,male,male      1.000000
# 2                      male,male,male      1.000000
# 3                      male,male,male      1.000000
# 4                    male,female,male      0.666667
# 5                 male,male,male,male      1.000000
# 6                           male,male      1.000000
# 7                      male,male,male      1.000000
# 8                      male,male,male      1.000000
# 9                      male,male,male      1.000000
# 10                   male,female,male      0.666667
# 11                male,male,male,male      1.000000
# 12                male,male,male,male      1.000000
# 13                male,male,male,male      1.000000
# 14                     male,male,male      1.000000
# 15                   female,male,male      0.666667
# 16                          male,male      1.000000
# 17                     male,male,male      1.000000
# 18                     male,male,male      1.000000
# 19                male,male,male,male      1.000000
# 20                     male,male,male      1.000000
# 21                     male,male,male      1.000000
# 22                          male,male      1.000000
# 23                          male,male      1.000000
# 24                          male,male      1.000000
# 25                          male,male      1.000000
# 26                        female,male      0.500000
# 27                     male,male,male      1.000000
# 28                 female,male,female      0.333333
# 29                          male,male      1.000000
# ...                               ...           ...
# 2482              male,male,male,male      1.000000
# 2483  male,male,male,male,male,female      0.833333
# 2484              male,male,male,male      1.000000
# 2485              male,male,male,male      1.000000
# 2486              male,male,male,male      1.000000
# 2487              male,male,male,male      1.000000
# 2488         male,male,male,male,male      1.000000
# 2489         male,male,male,male,male      1.000000
# 2490              male,male,male,male      1.000000
# 2491    male,male,male,male,male,male      1.000000
# 2492              male,male,male,male      1.000000
# 2493              male,male,male,male      1.000000
# 2494              male,male,male,male      1.000000
# 2495              male,male,male,male      1.000000
# 2496            male,female,male,male      0.750000
# 2497              male,male,male,male      1.000000
# 2498              male,male,male,male      1.000000
# 2499              male,male,male,male      1.000000
# 2500       male,male,male,female,male      0.800000
# 2501         male,male,male,male,male      1.000000
# 2502              male,male,male,male      1.000000
# 2503              male,male,male,male      1.000000
# 2504         male,male,male,male,male      1.000000
# 2505              male,male,male,male      1.000000
# 2506              male,male,male,male      1.000000
# 2507              male,male,male,male      1.000000
# 2508       male,male,female,male,male      0.800000
# 2509              male,male,male,male      1.000000
# 2510     male, male, male, male, male      0.200000
# 2511         male,male,male,male,male      1.000000
#
# [2512 rows x 14 columns]

# %%
episodesDataWithGenderComp.to_csv("C:\\Users\\Oliver\\Documents\\imbd episodes\\episodesDataWithGenderComp-4-24-18.csv")
